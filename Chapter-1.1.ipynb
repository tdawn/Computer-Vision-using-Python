# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as pl

pil_im = Image.open('./pcv_data/data/empire.jpg').convert('L')
                    
pl.figure()
pl.imshow(pil_im)
pl.gray()
pl.axis('off')
pl.show()

# %%
help(Image.open)
# Out:
# Help on function open in module PIL.Image:
#
# open(fp, mode='r')
#     Opens and identifies the given image file.
#
#     This is a lazy operation; this function identifies the file, but
#     the file remains open and the actual image data is not read from
#     the file until you try to process the data (or call the
#     :py:meth:`~PIL.Image.Image.load` method).  See
#     :py:func:`~PIL.Image.new`.
#
#     :param fp: A filename (string), pathlib.Path object or a file object.
#        The file object must implement :py:meth:`~file.read`,
#        :py:meth:`~file.seek`, and :py:meth:`~file.tell` methods,
#        and be opened in binary mode.
#     :param mode: The mode.  If given, this argument must be "r".
#     :returns: An :py:class:`~PIL.Image.Image` object.
#     :exception IOError: If the file cannot be found, or the image cannot be
#        opened and identified.

# %%
import os
filelist = os.listdir('pcv_data/data')
for infile in filelist:
    outfile = os.path.splitext(infile)[0] + ".jpg"
    print(outfile)
    if infile != outfile:
        try:
            Image.open(infile).save(outfile)
        except IOError:
            print("cannot convert", infile)
# Out:
# .DS_Store.jpg
# cannot convert .DS_Store
# alcatraz1.jpg
# alcatraz2.jpg
# AquaTermi_lowcontrast.jpg
# cannot convert AquaTermi_lowcontrast.JPG
# book_frontal.jpg
# cannot convert book_frontal.JPG
# book_perspective.jpg
# cannot convert book_perspective.bmp
# book_perspective.jpg
# cannot convert book_perspective.JPG
# boy_on_hill.jpg
# C-uniform03.jpg
# cannot convert C-uniform03.ppm
# calibration.jpg
# cannot convert calibration.JPG
# calibration_setup.jpg
# cannot convert calibration_setup.JPG
# ceramic-houses_t0.jpg
# cannot convert ceramic-houses_t0.png
# climbing_1_small.jpg
# climbing_2_small.jpg
# crans_1_small.jpg
# crans_2_small.jpg
# empire.jpg
# fisherman.jpg
# flower32_t0.jpg
# cannot convert flower32_t0.png
# fontimages.jpg
# cannot convert fontimages.zip
# houses.jpg
# cannot convert houses.png
# jkfaces.jpg
# cannot convert jkfaces.xml
# jkfaces.jpg
# cannot convert jkfaces.zip
# LICENSE.jpg
# cannot convert LICENSE.txt
# selectedfontimages.jpg
# cannot convert selectedfontimages.zip
# sf_view1.jpg
# sf_view2.jpg
# sudoku_images.jpg
# cannot convert sudoku_images.zip
# sunsets.jpg
# cannot convert sunsets.zip
# sunset_tree.jpg
# turningtorso1.jpg
# turningtorso1_points.jpg
# cannot convert turningtorso1_points.txt
# Univ1.jpg
# Univ2.jpg
# Univ3.jpg
# Univ4.jpg
# Univ5.jpg

# %%
box = (100,100,400,400)
region = pil_im.crop(box)
pl.figure()
pl.imshow(region)
pl.gray()
pl.axis('off')
pl.show()

# %%
print(region)
# Out:
# <PIL.Image.Image image mode=L size=300x300 at 0x23B589AD2B0>

# %%
def showimage(src):
    pl.figure()
    pl.imshow(src)
    pl.axis('off')
    pl.show()
    
showimage(region)

# %%
region = region.transpose(Image.ROTATE_180)
showimage(region)

# %%
pil_im.paste(region,box)
showimage(pil_im)

# %%
out = pil_im.resize((128,128))
showimage(out)

# %%
out = out.rotate(45)
showimage(out)
